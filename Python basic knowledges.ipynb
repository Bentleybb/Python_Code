# %% [markdown]
# 1. if - elif - else
# 2. for loop - nested for loop
# 3. while loop
# 4. functions
# 5. converting data types
# 6. build BMI(body mass index) calculator
# 7. Building an Automated File Sorter in File Explorer
# 8. BeautifulSoup and requests

# %% [markdown]
# # If - Elif - Else Statements
# ![If%20statement.jpg](attachment:If%20statement.jpg)

# %%
if 25 > 10:
    print('It worked!')
# Out:
# It worked!

# %%
if 25 < 10:
    print('It worked!')
else:
    print('It did not work...')
# Out:
# It did not work...

# %%
if 25 < 10:
    print('It worked!')
elif 25 < 30:
    print('elif worked!')
else:
    print('It did not work...')
# Out:
# elif worked!

# %%
if 25 < 10:
    print('It worked!')
elif 25 < 21:
    print('elif worked!')
elif 25 < 30:
    print('elif2 worked!')
else:
    print('It did not work...')
# Out:
# elif2 worked!

# %%
if (25 < 10) or (1 < 3):
    print('It worked!')
elif 25 < 21:
    print('elif worked!')
elif 25 < 30:
    print('elif2 worked!')
else:
    print('It did not work...')
# Out:
# It worked!

# %%
print('It worked!') if 25 < 30 else print('It did not work...')
# Out:
# It worked!

# %%
if (25 < 10) or (1 < 3):
    print('It worked!')
    if 10 > 5:
        print('This nested if statement worked.')
elif 25 < 21:
    print('elif worked!')
elif 25 < 30:
    print('elif2 worked!')
else:
    print('It did not work...')
# Out:
# It worked!
# This nested if statement worked.

# %% [markdown]
# # For Loops

# %% [markdown]
# ![For%20Loops.jpg](attachment:For%20Loops.jpg)

# %%
integers = [1,2,3,4,5]
for number in integers:
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
integers = [1,2,3,4,5]
for number in integers:
    print('Yelp!')
# Out:
# Yelp!
# Yelp!
# Yelp!
# Yelp!
# Yelp!

# %%
integers = [1,2,3,4,5]
for nut in integers:
    print(nut + nut)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
ice_cream_dict = {'name': 'Binli Han', 'weekly intake': 5, 'favorite ice cream': ['chocolate', 'vanilla', 'strawberry']}
for cream in ice_cream_dict.values():
    print(cream)
# Out:
# Binli Han
# 5
# ['chocolate', 'vanilla', 'strawberry']

# %%
ice_cream_dict = {'name': 'Binli Han', 'weekly intake': 5, 'favorite ice cream': ['chocolate', 'vanilla', 'strawberry']}
for key, value in ice_cream_dict.items():
    print(key, '>-', value)
# Out:
# name >- Binli Han
# weekly intake >- 5
# favorite ice cream >- ['chocolate', 'vanilla', 'strawberry']

# %% [markdown]
# ## Nested Loops

# %%
flavor = ('Vanilla', 'Chocolate', 'Mint', 'Strawberry')
topping = ('Hot Fudge', 'Marshmallows', 'Oreos')
for one in flavor:
    for two in topping:
        print(one, 'topped with', two)
# Out:
# Vanilla topped with Hot Fudge
# Vanilla topped with Marshmallows
# Vanilla topped with Oreos
# Chocolate topped with Hot Fudge
# Chocolate topped with Marshmallows
# Chocolate topped with Oreos
# Mint topped with Hot Fudge
# Mint topped with Marshmallows
# Mint topped with Oreos
# Strawberry topped with Hot Fudge
# Strawberry topped with Marshmallows
# Strawberry topped with Oreos

# %% [markdown]
# ![While%20Loops.jpg](attachment:While%20Loops.jpg)

# %%
number = 0

while number < 5:
     print(number)
     number = number + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
number = 0

while number < 5:
     print(number)
     if number == 3:
        break    # if here is continue, then it will run 3 all the way.
     number = number + 1
# Out:
# 0
# 1
# 2
# 3

# %%
number = 0

while number < 5:
     print(number)
     if number == 6:
        break
     number = number + 1   
else:
    print('No longer < 5')
# Out:
# 0
# 1
# 2
# 3
# 4
# No longer < 5

# %% [markdown]
# ![functions.jpg](attachment:functions.jpg)

# %%
def first_function():
    print('It is good!')

# %%
first_function()
# Out:
# It is good!

# %%
def number_squared(number):
    print(number**2)

# %%
number_squared(2)
# Out:
# 4

# %%
def number_squared_cust(number, power):
    print(number**power)

# %%
number_squared_cust(5,3)
# Out:
# 125

# %%
number_squared_cust(power = 5, number = 3) # Key words argument(multiple argument): don't have to put in specific position,
                                           # but need to mark it.
# Out:
# 243

# %%
def number_args(*number):
    print(number[0]* number[1])

# %%
number_args(5,6,1,2,8)
# Out:
# 30

# %%
args_tuple = (5,6,1,2,8)

def number_args(*number):
    print(number[0]* number[1])

# %%
number_args(args_tuple)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-b1b9a7c82d92> in <module>
# ----> 1 number_args(args_tuple)
#
# <ipython-input-36-818735c78e1a> in number_args(*number)
#       2
#       3 def number_args(*number):
# ----> 4     print(number[0]* number[1])
#
# IndexError: tuple index out of range

# %%
number_args(*args_tuple) # fixed
# Out:
# 30

# %%
def number_kward(**number):
    print('My number is: ' + number['integer'] + ', My other number is: ' + number['integer2'])

# %%
number_kward(integer = '53523', integer2 = '76885')
# Out:
# My number is: 53523, My other number is: 76885

# %% [markdown]
# # Converting Data Types

# %%
num_int = 7
type(num_int)
# Out:
# int

# %%
num_str = '7'
type(num_str)
# Out:
# str

# %%
num_sum = num_int + int(num_str)
print(num_sum)
# Out:
# 14

# %%
list_type = [1,2,3]
type(list_type)
# Out:
# list

# %%
tuple(list_type)
# Out:
# (1, 2, 3)

# %%
type(tuple(list_type))
# Out:
# tuple

# %%
list_type = [1,2,3,3,2,1,4,5,3,2,1,1]

# %%
set(list_type)
# Out:
# {1, 2, 3, 4, 5}

# %%
type(set(list_type))
# Out:
# set

# %%
dict_type = {'name': 'Bili', 'age': '36', 'gender': 'female'}
type(dict_type)
# Out:
# dict

# %%
dict_type.items()
# Out:
# dict_items([('name', 'Bili'), ('age', '36'), ('gender', 'female')])

# %%
dict_type.values()
# Out:
# dict_values(['Bili', '36', 'female'])

# %%
dict_type.keys()
# Out:
# dict_keys(['name', 'age', 'gender'])

# %%
list(dict_type.keys())
# Out:
# ['name', 'age', 'gender']

# %%
type(list(dict_type.keys()))
# Out:
# list

# %%
list(dict_type.values())
# Out:
# ['Bili', '36', 'female']

# %%
long_str = 'I am so happy when I become rich.'
list(long_str)
# Out:
# ['I',
#  ' ',
#  'a',
#  'm',
#  ' ',
#  's',
#  'o',
#  ' ',
#  'h',
#  'a',
#  'p',
#  'p',
#  'y',
#  ' ',
#  'w',
#  'h',
#  'e',
#  'n',
#  ' ',
#  'I',
#  ' ',
#  'b',
#  'e',
#  'c',
#  'o',
#  'm',
#  'e',
#  ' ',
#  'r',
#  'i',
#  'c',
#  'h',
#  '.']

# %% [markdown]
# # 6. Building a MBL Calculator

# %% [markdown]
# BMI = (weight in ponds *703)/(height in inches * height in inches).

# %%
name = input('Enter your name: ')
height = int(input('Enter your height in inches: '))
weight = int(input('Enter your weight in ponds: '))
BMI = (weight * 703)/(height * height)
print(BMI)

if BMI > 0:
    if (BMI <= 18.5):
        print(name + ' you are underweight.')
    elif (BMI <= 24.9):
        print(name + ' you are normalweight.')
    elif (BMI <= 29.9):
        print(name + ' you are overweight.')
    elif (BMI <= 34.9):
        print(name + ' you are obese.')
    elif (BMI <= 39.9):
        print(name + ' you are severely obese.')
    else: print(name + ' you are morbidly obese.')
else: print('Input valid value.')
# Out:
# Enter your name: Binli
# Enter your height in inches: 60
# Enter your weight in ponds: 200
# 39.05555555555556
# Binli you are severely obese.

# %% [markdown]
# # 7. Building an Automated File Sorter in File Explorer

# %%
import os, shutil

# %%
path = "/Users/TophMan/Documents/Data Analysis Tutorial/"

# %%
file_name = os.listdir(path)

# %%
folder_names = ['xlsx files', 'image files', 'csv files']

for loop in range(0,3):
    if not os.path.exists(path + folder_names[loop]):
        # print(path + folder_names[loop])
        os.makedirs(path + folder_names[loop])
        
for file in file_name:
    if ".csv" in file and not os.path.exists(path + "csv files/" + file):
        shutil.move(path + file, path + "csv files/" + file)
    elif ".xlsx" in file and not os.path.exists(path + "xlsx files/" + file):
        shutil.move(path + file, path + "xlsx files/" + file)
    elif ".jpg" in file and not os.path.exists(path + "image files/" + file):
        shutil.move(path + file, path + "image files/" + file)

# %% [markdown]
# # 8. HTML and Inspecting a Web Page

# %% [markdown]
# """
# <html>
#
# <head>
#     <tilt>My First Web Page</title>
# </head>
#
# <body>
#     <h1>My First Web Page</h1>
#     <p><b>Hello World Wide Web!</b></p>
#     <p><i>Hello World Wide Web!</i></p>
#     <p><u>Hello World Wide Web!</u></p>
#     <p>This is my first web page.</p>
#     <p>HTML tags can give <b><i>various</i></b>
#     <u>looks and format</u> to be content of this web page.</p>
# </body>
#
# </html>
#
# https://www.scrapethissite.com/pages/forms/
# """

# %% [markdown]
# # 8. BeautifulSoup and Requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
ur1 = 'https://www.scrapethissite.com/pages/forms/'
page = requests.get(ur1)

# %%
soup = BeautifulSoup(page.text, 'html')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping
#   </title>
#   <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components." name="description"/>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# ...

# %% [markdown]
# ## a. Find and Find All

# %%
soup.find('div')
# Out:
# <div class="container">
# <div class="col-md-12">
# <ul class="nav nav-tabs">
# <li id="nav-homepage">
# <a class="nav-link hidden-sm hidden-xs" href="/">
# <img id="nav-logo" src="/static/images/scraper-icon.png"/>
#                                 Scrape This Site
#                             </a>
# </li>
# <li id="nav-sandbox">
# <a class="nav-link" href="/pages/">
# <i class="glyphicon glyphicon-console hidden-sm hidden-xs"></i>
#                                 Sandbox
#                             </a>
# </li>
# <li id="nav-lessons">
# <a class="nav-link" href="/lessons/">
# <i class="glyphicon glyphicon-education hidden-sm hidden-xs"></i>
#                                 Lessons
#                             </a>
# </li>
# <li id="nav-faq">
# <a class="nav-link" href="/faq/">
# <i class="glyphicon glyphicon-flag hidden-sm hidden-xs"></i>
#                                 FAQ
#                             </a>
# </li>
# <li class="pull-right" id="nav-login">
# ...

# %%
soup.find_all('div', class_ = 'col-md-12')
# Out:
# [<div class="col-md-12">
#  <ul class="nav nav-tabs">
#  <li id="nav-homepage">
#  <a class="nav-link hidden-sm hidden-xs" href="/">
#  <img id="nav-logo" src="/static/images/scraper-icon.png"/>
#                                  Scrape This Site
#                              </a>
#  </li>
#  <li id="nav-sandbox">
#  <a class="nav-link" href="/pages/">
#  <i class="glyphicon glyphicon-console hidden-sm hidden-xs"></i>
#                                  Sandbox
#                              </a>
#  </li>
#  <li id="nav-lessons">
#  <a class="nav-link" href="/lessons/">
#  <i class="glyphicon glyphicon-education hidden-sm hidden-xs"></i>
#                                  Lessons
#                              </a>
#  </li>
#  <li id="nav-faq">
#  <a class="nav-link" href="/faq/">
#  <i class="glyphicon glyphicon-flag hidden-sm hidden-xs"></i>
#                                  FAQ
#                              </a>
#  </li>
#  <li class="pull-right" id="nav-login">
# ...

# %%
soup.find_all('p', class_ = 'lead')
# Out:
# [<p class="lead">
#                              Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components.
#                              Take a look at how pagination and search elements change the URL as your browse. Build a web scraper that can conduct searches and paginate through the results.
#                          </p>]

# %%
soup.find_all('p', class_ = 'lead').text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-89ee52316108> in <module>
# ----> 1 soup.find_all('p', class_ = 'lead').text
#
# /Applications/anaconda3/lib/python3.7/site-packages/bs4/element.py in __getattr__(self, key)
#    2079         """Raise a helpful exception to explain a common code fix."""
#    2080         raise AttributeError(
# -> 2081             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2082         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
soup.find('p', class_ = 'lead').text.strip()
# Out:
# 'Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components.\n                            Take a look at how pagination and search elements change the URL as your browse. Build a web scraper that can conduct searches and paginate through the results.'

# %%
soup.find_all('th')
# Out:
# [<th>
#                              Team Name
#                          </th>,
#  <th>
#                              Year
#                          </th>,
#  <th>
#                              Wins
#                          </th>,
#  <th>
#                              Losses
#                          </th>,
#  <th>
#                              OT Losses
#                          </th>,
#  <th>
#                              Win %
#                          </th>,
#  <th>
#                              Goals For (GF)
#                          </th>,
#  <th>
#                              Goals Against (GA)
#                          </th>,
#  <th>
#                              + / -
#                          </th>]

# %%
soup.find('th').text.strip()
# Out:
# 'Team Name'
